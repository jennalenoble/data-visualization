# %% [markdown]
# # Module 2: Visual Encoding Channels

# %% [markdown]
# ### Area Charts

# %%
import altair as alt
from vega_datasets import data
import pandas as pd

# %%
gm = pd.read_csv("data/world-data-gapminder.csv", parse_dates = ['year'])
gm
# Out:
#            country       year  population  region          sub_region  \
# 0      Afghanistan 1800-01-01     3280000    Asia       Southern Asia
# 1      Afghanistan 1801-01-01     3280000    Asia       Southern Asia
# 2      Afghanistan 1802-01-01     3280000    Asia       Southern Asia
# 3      Afghanistan 1803-01-01     3280000    Asia       Southern Asia
# 4      Afghanistan 1804-01-01     3280000    Asia       Southern Asia
# ...            ...        ...         ...     ...                 ...
# 38977     Zimbabwe 2014-01-01    15400000  Africa  Sub-Saharan Africa
# 38978     Zimbabwe 2015-01-01    15800000  Africa  Sub-Saharan Africa
# 38979     Zimbabwe 2016-01-01    16200000  Africa  Sub-Saharan Africa
# 38980     Zimbabwe 2017-01-01    16500000  Africa  Sub-Saharan Africa
# 38981     Zimbabwe 2018-01-01    16900000  Africa  Sub-Saharan Africa
#
#       income_group  life_expectancy  income  children_per_woman  \
# 0              Low             28.2     603                7.00
# 1              Low             28.2     603                7.00
# 2              Low             28.2     603                7.00
# 3              Low             28.2     603                7.00
# 4              Low             28.2     603                7.00
# ...            ...              ...     ...                 ...
# 38977          Low             57.0    1910                3.90
# 38978          Low             58.3    1890                3.84
# 38979          Low             59.3    1860                3.76
# 38980          Low             59.8    1910                3.68
# 38981          Low             60.2    1950                3.61
#
#        child_mortality  pop_density  co2_per_capita  years_in_school_men  \
# 0                469.0          NaN             NaN                  NaN
# 1                469.0          NaN             NaN                  NaN
# 2                469.0          NaN             NaN                  NaN
# 3                469.0          NaN             NaN                  NaN
# 4                469.0          NaN             NaN                  NaN
# ...                ...          ...             ...                  ...
# 38977             64.3         39.8            0.78                 10.9
# 38978             59.9         40.8             NaN                 11.1
# 38979             56.4         41.7             NaN                  NaN
# 38980             56.8         42.7             NaN                  NaN
# 38981             55.5         43.7             NaN                  NaN
#
#        years_in_school_women
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 38977                   10.0
# 38978                   10.2
# 38979                    NaN
# 38980                    NaN
# 38981                    NaN
#
# [38982 rows x 14 columns]

# %%
gm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38982 entries, 0 to 38981
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   country                38982 non-null  object
#  1   year                   38982 non-null  datetime64[ns]
#  2   population             38982 non-null  int64
#  3   region                 38982 non-null  object
#  4   sub_region             38982 non-null  object
#  5   income_group           38982 non-null  object
#  6   life_expectancy        38982 non-null  float64
#  7   income                 38982 non-null  int64
#  8   children_per_woman     38982 non-null  float64
#  9   child_mortality        38980 non-null  float64
#  10  pop_density            12282 non-null  float64
#  11  co2_per_capita         16285 non-null  float64
#  12  years_in_school_men    8188 non-null   float64
#  13  years_in_school_women  8188 non-null   float64
# dtypes: datetime64[ns](1), float64(7), int64(2), object(4)
# memory usage: 4.2+ MB

# %%
alt.Chart('https://website.com/data.csv').mark_line().encode(
    x='column1:T', #Temporal
    y='column2:Q') #Quantitative
# Out:
# alt.Chart(...)

# %%
gm_url = 'https://raw.githubusercontent.com/UBC-MDS/exploratory-data-viz/main/chapters/en/slides/module2/data/world-data-gapminder.csv'
alt.Chart(gm_url).mark_line().encode(
    x='year:T',
    y='population:Q')
# Out:
# alt.Chart(...)

# %%
alt.Chart(gm_url).mark_line().encode(
    x='year:T',
    y='sum(population):Q')
# Out:
# alt.Chart(...)

# %%
alt.Chart(gm_url).mark_line().encode(
    x='year:T',
    y=alt.Y('sum(population):Q', title='World population'))
# Out:
# alt.Chart(...)

# %%
alt.Chart(gm_url).mark_area().encode(
    x='year:T',
    y=alt.Y('sum(population):Q', title='World population'))
# Out:
# alt.Chart(...)

# %%
alt.Chart(gm_url).mark_area().encode(
    alt.X('year:T'),
    alt.Y('sum(population):Q', title='Cumulative population of stacked regions'),
    color='region:N')
# Out:
# alt.Chart(...)

# %%
alt.Chart(gm_url).mark_line().encode(
    alt.X('year:T'),
    alt.Y('sum(population):Q', title='Cumulative population of stacked regions'),
    color='region:N')
# Out:
# alt.Chart(...)

# %%
alt.Chart(gm_url).mark_area().encode(
    alt.X('year:T'),
    alt.Y('mean(children_per_woman):Q', title='Average children per woman worldwide'))
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Bar Charts and Histograms

# %%
gm2018 = gm[gm['year']=='2018']
gm2018
# Out:
#                    country       year  population    region  \
# 218            Afghanistan 2018-01-01    36400000      Asia
# 437                Albania 2018-01-01     2930000    Europe
# 656                Algeria 2018-01-01    42000000    Africa
# 875                 Angola 2018-01-01    30800000    Africa
# 1094   Antigua and Barbuda 2018-01-01      103000  Americas
# ...                    ...        ...         ...       ...
# 38105            Venezuela 2018-01-01    32400000  Americas
# 38324              Vietnam 2018-01-01    96500000      Asia
# 38543                Yemen 2018-01-01    28900000      Asia
# 38762               Zambia 2018-01-01    17600000    Africa
# 38981             Zimbabwe 2018-01-01    16900000    Africa
#
#                             sub_region  income_group  life_expectancy  income  \
# 218                      Southern Asia           Low             58.7    1870
# 437                    Southern Europe  Upper middle             78.0   12400
# 656                    Northern Africa  Upper middle             77.9   13700
# 875                 Sub-Saharan Africa  Lower middle             65.2    5850
# 1094   Latin America and the Caribbean          High             77.6   21000
# ...                                ...           ...              ...     ...
# 38105  Latin America and the Caribbean  Upper middle             75.9   14200
# 38324               South-eastern Asia  Lower middle             74.9    6550
# 38543                     Western Asia           Low             67.1    2430
# 38762               Sub-Saharan Africa  Lower middle             59.5    3870
# 38981               Sub-Saharan Africa           Low             60.2    1950
#
#        children_per_woman  child_mortality  pop_density  co2_per_capita  \
# 218                  4.33            65.90         55.7             NaN
# 437                  1.71            12.90        107.0             NaN
# 656                  2.64            23.10         17.6             NaN
# 875                  5.55            81.60         24.7             NaN
# 1094                 2.03             7.89        234.0             NaN
# ...                   ...              ...          ...             ...
# 38105                2.27            15.40         36.7             NaN
# 38324                1.95            20.20        311.0             NaN
# 38543                3.79            51.90         54.8             NaN
# 38762                4.87            59.50         23.7             NaN
# 38981                3.61            55.50         43.7             NaN
#
#        years_in_school_men  years_in_school_women
# 218                    NaN                    NaN
# 437                    NaN                    NaN
# 656                    NaN                    NaN
# 875                    NaN                    NaN
# 1094                   NaN                    NaN
# ...                    ...                    ...
# 38105                  NaN                    NaN
# 38324                  NaN                    NaN
# 38543                  NaN                    NaN
# 38762                  NaN                    NaN
# 38981                  NaN                    NaN
#
# [178 rows x 14 columns]

# %%
alt.Chart(gm2018).mark_bar().encode(
    alt.X('region'),
    alt.Y('sum(population)', title='Population'))
# Out:
# alt.Chart(...)

# %%
alt.Chart(gm2018).mark_bar().encode(
    alt.X('sum(population)', title='Population'),
    alt.Y('region'))
# Out:
# alt.Chart(...)

# %%
alt.Chart(gm2018).mark_bar().encode(
    alt.X('count()', title='Number of countries'),
    alt.Y('region'))
# Out:
# alt.Chart(...)

# %%
alt.Chart(gm2018).mark_bar().encode(
    alt.X('count()', title='Number of countries'),
    alt.Y('region', sort='x'))
# Out:
# alt.Chart(...)

# %%
alt.Chart(gm2018).mark_bar().encode(
    alt.X('count()', title='Number of countries'),
    alt.Y('region', sort=['Oceania', 'Americas', 'Europe', 'Asia', 'Africa']))
# Out:
# alt.Chart(...)

# %%
alt.Chart(gm2018).mark_bar().encode(
    alt.X('count()', title='Number of countries'),
    alt.Y('region', sort='-x'))
# Out:
# alt.Chart(...)

# %%
my_order = ['Africa', 'Europe', 'Oceania', 'Asia', 'Americas']
alt.Chart(gm2018).mark_bar().encode(
    alt.X('count()', title = "Count"),
    alt.Y('region', sort=my_order))
# Out:
# alt.Chart(...)

# %%
alt.Chart(gm2018).mark_bar().encode(
    alt.X('life_expectancy'),
    alt.Y('count()'))
# Out:
# alt.Chart(...)

# %%
alt.Chart(gm2018).mark_bar().encode(
    alt.X('life_expectancy', bin=True),
    alt.Y('count()'))
# Out:
# alt.Chart(...)

# %%
alt.Chart(gm2018).mark_bar().encode(
    alt.X('life_expectancy', bin=alt.Bin(maxbins=30), title='Life expectancy'),
    alt.Y('count()'))
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Creating Subplots via Faceting

# %%
alt.Chart(gm2018).mark_bar().encode(
    alt.X('life_expectancy', bin=alt.Bin(maxbins=30)),
    alt.Y('count()'),
    alt.Color('region'))
# Out:
# alt.Chart(...)

# %%
alt.Chart(gm2018).mark_bar(opacity=0.7).encode(
    alt.X('life_expectancy', bin=alt.Bin(maxbins=30)),
    alt.Y('count()', stack=False),
    alt.Color('region'))
# Out:
# alt.Chart(...)

# %%
alt.Chart(gm2018).mark_bar().encode(
    alt.X('life_expectancy', bin=alt.Bin(maxbins=30)),
    alt.Y('count()'),
    alt.Color('region')
).properties(width=200, height=150
            ).facet('region')
# Out:
# alt.FacetChart(...)

# %%
alt.Chart(gm2018).mark_bar().encode(
    alt.X('life_expectancy', bin=alt.Bin(maxbins=30)),
    alt.Y('count()'),
    alt.Color('region')
).properties(width=200, height=50
            ).facet('region', columns=2)
# Out:
# alt.FacetChart(...)

# %%
alt.Chart(gm2018).mark_bar().encode(
    alt.X('life_expectancy', bin=alt.Bin(maxbins=30)),
    alt.Y('count()'),
    alt.Color('region')
).properties(width=200, height=140
            ).facet('region', columns=3)
# Out:
# alt.FacetChart(...)

# %%
alt.Chart(gm2018[gm2018['income_group'].isin(['High','Low'])]).mark_bar().encode(
    alt.X('life_expectancy', bin=alt.Bin(maxbins=30)),
    alt.Y('count()'),
    alt.Color('region')
).properties(width=200, height=140
            ).facet(column='region', row='income_group')
# Out:
# alt.FacetChart(...)

# %%
income_order = ['High', 'Upper middle', 'Lower middle', 'Low']
alt.Chart(gm2018[gm2018['region'].isin(['Africa'])]).mark_point().encode(
    alt.X('children_per_woman'),
    alt.Y('child_mortality'),
    alt.Color('income_group', sort=income_order)
).properties(width=200, height=140
            ).facet('sub_region')
# Out:
# alt.FacetChart(...)

# %%
alt.Chart(gm2018[gm2018['region'].isin(['Africa'])]).mark_bar().encode(
    alt.X('count()', title='Number of countries'),
    alt.Y('sub_region'),
    alt.Color('income_group', sort=income_order)
).properties(width=200)
# Out:
# alt.Chart(...)

# %%
alt.Chart(gm2018[gm2018['region'].isin(['Africa'])]).mark_bar().encode(
    alt.X('count()', title='Number of countries'),
    alt.Y('income_group', sort=income_order),
    alt.Color('income_group', sort=income_order, legend=None)
).properties(width=200).facet('sub_region')
# Out:
# alt.FacetChart(...)
